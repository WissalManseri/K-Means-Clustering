# %% [markdown]
# <a href="https://colab.research.google.com/github/WISSAL-MN/K-Means-Clustering/blob/main/Apprentissage_non_suppervis%C3%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'https://github.com/WISSAL-MN'
# Out:
# 'https://github.com/WISSAL-MN'

# %% [markdown]
# **Apprentissage Non-Supervisé**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# 1. **K**-**Means** **Clustering**:

# %%
from sklearn.cluster import KMeans
# on importe l'éstmateur  KMeans depuis le module cluster

# %%
# Génération de données
X, y = make_blobs(n_samples=100, centers=3, cluster_std=0.4, random_state=0)
plt.scatter(X[:,0], X[:,1])

# %%
model = KMeans(n_clusters=3)
model.fit(X)
model.predict(X)
plt.scatter(X[:,0], X[:,1], c=model.predict(X))
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], c='r')
model.score(X)
# Out:
# -30.87053128014068

# %% [markdown]
# **Elbow** **Method**

# %%
inertia = []
K_range = range(1, 20)
for k in K_range:
    model = KMeans(n_clusters=k).fit(X)
    inertia.append(model.inertia_)

plt.plot(K_range, inertia)
plt.xlabel('nombre de clusters')
plt.ylabel('Cout du modele (Inertia)')
# Out:
# Text(0, 0.5, 'Cout du modele (Inertia)')
